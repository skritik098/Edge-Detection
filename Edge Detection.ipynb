# %%
import numpy as np
import cv2
import glob as gl

# %%
def auto_canny(image, sigma=0.33):
    # compute the median of the single channel pixel intensities
    v = np.median(image)
 
    # apply automatic Canny edge detection using the computed median
    lower = int(max(0, (1.0 - sigma) * v))
    upper = int(min(255, (1.0 + sigma) * v))
    edged = cv2.Canny(image, lower, upper)
 
    # return the edged image
    return edged

# %%
import face_recognition as fr

# %%
img = fr.load_image_file('/Users/kritiksachdeva/Desktop/Photo on 05-08-18 at 7.17 AM.jpg')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow?

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray)

# %%
blurr = cv2.GaussianBlur(gray,(5,5),0)

# %%
plt.imshow(blurr)

# %%
wide = cv2.Canny(blurr,10,200)
tight = cv2.Canny(blurr,200,250)
auto = auto_canny(blurr)

# %%
cv2.imshow("Original", img)
cv2.imshow("Edges", np.hstack([wide, tight, auto]))
cv2.waitKey(0)

# %%
np.hstack?

# %%
import time

# %%
st = time.time()
plt.figure(0)
plt.imshow(wide)
end = time.time()
print(end-st,"*2f")
st = time.time()
plt.figure(1)
plt.imshow(tight)
end = time.time()
print(end-st,"*2f")
st = time.time()
plt.figure(2)
plt.imshow(auto)
end = time.time()
print(end-st,'*2f')
# Out:
# (0.09595489501953125, '*2f')
# (0.07791900634765625, '*2f')
# (0.08696293830871582, '*2f')

# %%
cap = cv2.VideoCapture(0)
while True:
    ret, img = cap.read()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    blurr = cv2.GaussianBlur(gray,(3,3),0)
    #wide = cv2.Canny(blurr,10,200)
    auto = auto_canny(blurr)
    cv2.imshow('Hi',auto)
    if cv2.waitKey(1) == 13:
        break
cap.release()
cv2.destroyAllWindows()

# %%
import imutils as iu

# %%
frame = iu.auto_canny(blurr,sigma=3)

# %%
plt.imshow(frame)

# %%
frame = iu.auto_canny(blurr,sigma=2)

# %%
plt.imshow(frame)

# %%
plt.imshow(blurr)

# %%
g = cv2.GaussianBlur(blurr,(3,3),0)

# %%
fr = cv2.Laplacian(blurr,cv2.CV_16U)

# %%
plt.imshow(fr,cmap='gray')

# %%
gfra = iu.auto_canny(fr,sigma=3)

# %%
plt.imshow(gfra)

# %%
cap = cv2.VideoCapture(0)
while True:
    ret, img = cap.read()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    blurr = cv2.GaussianBlur(gray,(3,3),0)
    #wide = cv2.Canny(blurr,10,200)
    #auto = auto_canny(blurr)
    auto = cv2.Laplacian(blurr,cv2.CV_8UC4)
    cv2.imshow('Hi',auto)
    if cv2.waitKey(1) == 13:
        break
cap.release()
cv2.destroyAllWindows()

# %%
I = fr.load_image_file('/Users/kritiksachdeva/Desktop/Screen Shot 2018-09-04 at 8.37.11 PM.png')

# %%
plt.imshow(I)

# %%
i = cv2.cvtColor(I,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(i)

# %%
b = cv2.GaussianBlur(i,(5,5),0)

# %%
plt.imshow(b)

# %%
L = cv2.Laplacian(b,cv2.CV_8U)

# %%
plt.imshow(L)

# %%
k = cv2.cvtColor(L,cv2.COLOR_GRAY2BGR)

# %%
plt.imshow(k,cmap='gray')

# %%
face = fr.face_locations(L,model='cnn')
face2 = fr.face_locations(L,model='hog')

# %%
face,face2
# Out:
# ([], [])

# %%
for (x,y,w,h) in face:
    (p,q,r,s) = (x,y,w,h)

# %%
for (x,y,w,h) in face2:
    (p2,q2,r2,s2) = (x,y,w,h)

# %%
#face1Ext = L[p:r,s:q]
face2Ext = L[p2:r2,s2:q2]

# %%
plt.imshow(face2Ext)
